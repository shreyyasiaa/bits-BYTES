# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, LineString
import plotly_express as px
import networkx as nx
import osmnx as ox
ox.settings.log_console=True
import folium
import numpy as np 
import geopy
from datetime import datetime
import csv
from geopy.distance import geodesic
from math import sin, cos, sqrt, atan2, radians

# %% [raw]
# from geopy.geocoders import Nominatim
# locator = Nominatim(user_agent = "myfunc")
# addr = input("Enter the location name:")
# location = locator.geocode(addr)
# print(location.latitude, location.longitude)
# print(location.point)
# #print(type(location.point))
# my_map=folium.Map()
# folium.Marker(location=[location.latitude, location.longitude],icon=folium.Icon(color="red",icon="circle")).add_to(my_map)
# my_map
# # Add the locations which are not available in geopy module to a file

# %% [raw]
# from geopy.geocoders import Nominatim
# locator = Nominatim(user_agent = "myfunc")
# addr = input("Enter the location name:")
# location = locator.geocode(addr)
# print(location.point)

# %%
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent = "myfunc")
addr = input("Enter the location name:")
point_1= locator.geocode(addr)
print(point_1.latitude,point_1.longitude)
# Out:
# Enter the location name:Bangalore
# 12.9767936 77.590082

# %%
df_rnfl = pd.read_csv("rainfall.csv")

# %%
df_rnfl.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0                STATE_UT_NAME        DISTRICT    JAN   FEB  \
# 0             0  ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9
# 1             1  ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0
# 2             2  ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9
# 3             3            ARUNACHAL PRADESH           LOHIT   42.2  80.8
# 4             4            ARUNACHAL PRADESH      EAST SIANG   33.3  79.5
# ..          ...                          ...             ...    ...   ...
# 636         636                       KERALA          IDUKKI   13.4  22.1
# 637         637                       KERALA        KASARGOD    2.3   1.0
# 638         638                       KERALA  PATHANAMTHITTA   19.8  45.2
# 639         639                       KERALA         WAYANAD    4.8   8.3
# 640         640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7
#
# ...

# %%
df_rnfl.describe()
# Out:
#        Unnamed: 0         JAN         FEB         MAR         APR         MAY  \
# count  641.000000  641.000000  641.000000  641.000000  641.000000  641.000000
# mean   320.000000   18.355070   20.984399   30.034789   45.543214   81.535101
# std    185.185043   21.082806   27.729596   45.451082   71.556279  111.960390
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.900000
# 25%    160.000000    6.900000    7.000000    7.000000    5.000000   12.100000
# 50%    320.000000   13.300000   12.300000   12.700000   15.100000   33.900000
# 75%    480.000000   19.200000   24.100000   33.200000   48.300000   91.900000
# max    640.000000  144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   641.000000   641.000000   641.000000  641.000000  641.000000
# mean    196.007332   326.033697   291.152262  194.609048   90.446334
# ...

# %%
month_dict = {1:"JAN",2:"FEB",3:"MAR",4:"APR",5:"MAY",6:"JUN",7:"JUL",8:"AUG",9:"SEP",10:"OCT",11:"NOV",12:"DEC"}
mon_no = datetime.now().month
mon_curr = month_dict[mon_no]

# %%
no_rows = df_rnfl.shape[0]
no_rows
# Out:
# 641

# %%
def distance(lat1, lon1, lat2, lon2):
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c

    return distance

# %%
min_dist = 0;
district_name = ""
i = 0;
while i<641:
    dist = distance(point_1.latitude,point_1.longitude,df_rnfl.loc[i,'lat'],df_rnfl.loc[i,'longs'])
    if i == 0:
        min_dist = dist
        district_name = df_rnfl.loc[i,'DISTRICT']
        print(i)
        print(district_name)
        i+=1
    else :
        if dist < min_dist:
            min_dist = dist
            district_name = df_rnfl.loc[i,'DISTRICT']
            print(district_name)
            print(i)
    i+=1
print(district_name)
# Out:
# 0
# NICOBAR
# NICOBAR
